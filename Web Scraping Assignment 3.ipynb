# %% [markdown]
# # Question 1

# %%
# Let's now import all the required libraries.
import selenium
import pandas as pd
import warnings
warnings.filterwarnings("ignore")
from selenium import webdriver
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException
from selenium.webdriver.common.by import By
import time
from time import sleep

# %%
#Connecting to the driver

driver=webdriver.Chrome(r"chromedriver.exe")

# %%
#Opening the Amazon website on automated website
driver.get("https://www.amazon.in/")
val=input("Enter the product: ")
# Out:
# Enter the product: headphones

# %%
#Entering the product name
search=driver.find_element(By.XPATH,"/html/body/div[1]/header/div/div[1]/div[2]/div/form/div[2]/div[1]/input")
search.send_keys(val)

# %%
clk=driver.find_element(By.XPATH,"/html/body/div[1]/header/div/div[1]/div[2]/div/form/div[3]/div/span/input")
clk.click()

# %% [markdown]
# # Question2

# %%
start_page = 0
end_page = 2
urls = []
for page in range(start_page,end_page+1):
    try:
        page_urls = driver.find_elements(By.XPATH,'//a[@class="a-link-normal s-no-outline"]')
        
        # appending all the urls on current page to urls list
        for url in page_urls:
            urls.append(url.get_attribute("href"))
            
        print("Product urls of page {} has been scraped.".format(page+1))
        
        # Moving to next page
        nxt_button = driver.find_element(By.XPATH,'//a[@class="s-pagination-item s-pagination-next s-pagination-button s-pagination-separator"]')      # Locating the next_button which is active
        nxt_button.click()                                                    # Clicking the next button
        time.sleep(5)                                                         # time delay of 5 seconds
                    
    except StaleElementReferenceException as e:             # Handling StaleElement Exception   
        print("Stale Exception")
        next_page = nxt_button.get_attribute('href')        # Extracting the url of next page
        driver.get(next_page)                               # ReLoading the next page
# Out:
# Product urls of page 1 has been scraped.
# Product urls of page 2 has been scraped.
# Product urls of page 3 has been scraped.

# %%
brand=[]
name=[]
price=[]
exchange=[]
exp_del=[]
availability=[]
prod_url=[]

# %%
for url in urls:
    driver.get(url)                                                        # Loading the webpage by url
    #time.sleep(2)
    
    try:
        a=driver.find_element(By.XPATH,'//a[@id="bylineInfo"]')      # Extracting Brand from xpath
        brand.append(a.text)
    except NoSuchElementException:
        brand.append('-')
    
    try:
        b=driver.find_element(By.XPATH,'//h1[@id="title"]/span')      # Extracting Name from xpath
        name.append(b.text)
    except NoSuchElementException:
        name.append('-')
    
    try:
        c=driver.find_element(By.XPATH,'//span[@class="a-price a-text-price a-size-medium apexPriceToPay"]')  # Extracting Price from xpath
        price.append(c.text)
    except NoSuchElementException:
        price.append('-')
    
    try:
        d=driver.find_element('id','RETURNS_POLICY')     # Extracting Exchange Policy
        exchange.append(d.text)
    except NoSuchElementException:
        exchange.append('-')
        
    prod_url.append(url)                                                            # Saving url
    time.sleep(2)

# %%
#Scraping Availability
for url in urls:
    driver.get(url)
    f=driver.find_element(By.XPATH,"//*[@id='availability']/span")
    availability.append(f.text)
   
    g=driver.find_element("id","mir-layout-DELIVERY_BLOCK-slot-PRIMARY_DELIVERY_MESSAGE_LARGE")         # Extracting Expected Delivery from xpath
    exp_del.append(g.text)

# %%
data=pd.DataFrame({"Brand":brand,"Name":name,"Price":price,"Exchange":exchange,"Expected Delivery":exp_del,"Availability":availability,"Product URL":prod_url})
data
# Out:
#                          Brand  \
# 0   Visit the Sennheiser Store
# 1          Visit the JBL Store
# 2         Visit the boAt Store
# 3            Brand: ShopMagics
# 4         Visit the boAt Store
# ..                         ...
# 65       Visit the PTron Store
# 66               Brand: UrCart
# 67        Visit the boAt Store
# 68        Visit the boAt Store
# 69   Visit the ZEBRONICS Store
#
#                                                  Name      Price  \
# 0   Sennheiser HD 450SE Bluetooth 5.0 Wireless Ove...  ₹6,990.00
# 1   New JBL Tune 130NC TWS | Active Noise Cancella...  ₹3,799.00
# 2   boAt Rockerz 450 Bluetooth On Ear Headphones w...    ₹998.00
# 3   Bluetooth Neckband for Xiaomi Redmi Note 5 Pro...          -
# 4   boAt Rockerz 450 Bluetooth On Ear Headphones w...    ₹999.00
# ..                                                ...        ...
# 65  pTron Bassbuds Duo in Ear Earbuds with 32Hrs T...    ₹599.00
# ...

# %% [markdown]
# # Question 3

# %%
# Let's now import all the required libraries.
import selenium
import pandas as pd
import warnings
warnings.filterwarnings("ignore")
from selenium import webdriver
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException
from selenium.webdriver.common.by import By
import time
from time import sleep
from selenium.webdriver.common.keys import Keys
import urllib

# %%
import urllib
#Connecting to the driver
driver=webdriver.Chrome(r"chromedriver.exe")

# %%
#Opening the website on automated website
driver.get("https://images.google.com/")

# %%
search_bar = driver.find_element(By.XPATH,"//input[@class='gLFyf gsfi']")    # Finding the search bar using it's xpath
search_bar.click()

# %%
search_bar.send_keys("fruits")       # Inputing "banana" keyword to search images
search_bar.send_keys(Keys.ENTER)       # Clicking the search button
#Scraping images
url=[]
images = driver.find_elements(By.XPATH,'//img[@class="rg_i Q4LuWd"]')
for i in images:
    url.append(i.get_attribute("src"))

# %%
url
# Out:
# ['data:image/jpeg;base64,...',
#  'data:image/jpeg;base64,...',
#  'data:image/jpeg;base64,...',
#  'data:image/jpeg;base64,...',
#  'data:image/jpeg;base64,...',
#  'data:image/jpeg;base64,...',
#  'data:image/jpeg;base64,...',
#  'data:image/jpeg;base64,...',
#  'data:image/jpeg;base64,...',
#  'data:image/jpeg;base64,...',
#  'data:image/jpeg;base64,...',
#  'data:image/jpeg;base64,...',
#  'data:image/jpeg;base64,...',
#  'data:image/jpeg;base64,...',
#  'data:image/jpeg;base64,...',
#  'data:image/jpeg;base64,...',
#  'data:image/jpeg;base64,...',
#  'data:image/jpeg;base64,...',
#  'data:image/jpeg;base64,...',
#  'data:image/jpeg;base64,...',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None]

# %% [markdown]
# # Question 4

# %%
# Let's now import all the required libraries.
import selenium
import pandas as pd
import warnings
warnings.filterwarnings("ignore")
from selenium import webdriver
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException
from selenium.webdriver.common.by import By

# %%
#Connecting to the driver
driver=webdriver.Chrome(r"chromedriver.exe")

# %%
#Opening the Flipkart website on automated website
driver.get("https://www.flipkart.com/")

# %%
#Entering Smartphone in the search field
prod=driver.find_element(By.CLASS_NAME,"_3704LK")
prod.send_keys("Smartphone")
clk=driver.find_element(By.CLASS_NAME,"L0Z3Pu")
clk.click()

# %%
Name=[]
brand=[]
Color=[]
Storage_RAM_ROM=[]
camera=[]
disp=[]
ProcessorAndCores=[]
Battery=[]
Price=[]
url=[]

# %%
#scraping the Brand_Name and color
BName=driver.find_elements(By.XPATH,"//div[@class='_4rR01T']")
for i in BName:
    if i.text is None :
        Name.append("--") 
    else:
        Name.append(i.text)
a=[]
for i1 in range(0,len(Name)):
    a.append(Name[i1].split("("))


for i2 in range(0,len(a)):
    Color.append(a[i2][1])
    brand.append(a[i2][0])

# %%
#scraping the Storage_RAM_ROM 
ram=driver.find_elements(By.XPATH,"//ul[@class='_1xgFaf']//li[1]")
for i in ram:
    if i.text is None :
        Storage_RAM_ROM.append("--") 
    else:
        Storage_RAM_ROM.append(i.text)
print(Storage_RAM_ROM)
# Out:
# ['4 GB RAM | 64 GB ROM | Expandable Upto 1 TB', '4 GB RAM | 64 GB ROM | Expandable Upto 1 TB', '4 GB RAM | 64 GB ROM | Expandable Upto 1 TB', '128 GB ROM', '128 GB ROM', '64 GB ROM', '3 GB RAM | 32 GB ROM | Expandable Upto 512 GB', '4 GB RAM | 64 GB ROM | Expandable Upto 512 GB', '4 GB RAM | 64 GB ROM | Expandable Upto 1 TB', '64 GB ROM', '128 GB ROM', '2 GB RAM | 32 GB ROM | Expandable Upto 1 TB', '2 GB RAM | 32 GB ROM | Expandable Upto 1 TB', '2 GB RAM | 32 GB ROM | Expandable Upto 1 TB', '3 GB RAM | 32 GB ROM | Expandable Upto 1 TB', '3 GB RAM | 32 GB ROM | Expandable Upto 1 TB', '4 GB RAM | 64 GB ROM | Expandable Upto 1 TB', '4 GB RAM | 64 GB ROM | Expandable Upto 1 TB', '128 GB ROM', '3 GB RAM | 32 GB ROM | Expandable Upto 512 GB', '4 GB RAM | 64 GB ROM | Expandable Upto 1 TB', '3 GB RAM | 32 GB ROM | Expandable Upto 1 TB', '4 GB RAM | 64 GB ROM | Expandable Upto 1 TB', '4 GB RAM | 64 GB ROM | Expandable Upto 1 TB']

# %%
#scraping the Camera 
PC=driver.find_elements(By.XPATH,"//ul[@class='_1xgFaf']//li[3]")
for i in PC:
    if i.text is None :
        camera.append("--") 
    else:
        camera.append(i.text)
print(camera)
# Out:
# ['50MP + 5MP + 2MP | 8MP Front Camera', '50MP + 5MP + 2MP | 8MP Front Camera', '50MP + 5MP + 2MP | 8MP Front Camera', '12MP + 12MP | 12MP Front Camera', '12MP + 12MP | 12MP Front Camera', '12MP + 12MP | 12MP Front Camera', '13MP + 2MP + 2MP | 5MP Front Camera', '13MP + 2MP + 2MP | 5MP Front Camera', '50MP + 2MP | 5MP Front Camera', '12MP + 12MP | 12MP Front Camera', '12MP + 12MP | 12MP Front Camera', '8MP Rear Camera | 5MP Front Camera', '8MP Rear Camera | 5MP Front Camera', '8MP Rear Camera | 5MP Front Camera', '50MP + 0.3MP | 5MP Front Camera', '50MP + 0.3MP | 5MP Front Camera', '50MP + 0.3MP | 5MP Front Camera', '50MP + 0.3MP | 5MP Front Camera', '12MP + 12MP | 12MP Front Camera', '13MP + 2MP + 2MP | 5MP Front Camera', '50MP + 2MP | 5MP Front Camera', '50MP + 0.3MP | 5MP Front Camera', '50MP + 0.3MP | 5MP Front Camera', '50MP + 2MP | 5MP Front Camera']

# %%
#scraping the Display
d=driver.find_elements(By.XPATH,"//ul[@class='_1xgFaf']//li[2]")
for i in d:
    if i.text is None :
        disp.append("--") 
    else:
        disp.append(i.text)
print(disp)
# Out:
# ['16.76 cm (6.6 inch) Full HD+ Display', '16.76 cm (6.6 inch) Full HD+ Display', '16.76 cm (6.6 inch) Full HD+ Display', '15.49 cm (6.1 inch) Liquid Retina HD Display', '15.49 cm (6.1 inch) Liquid Retina HD Display', '15.49 cm (6.1 inch) Liquid Retina HD Display', '16.59 cm (6.53 inch) HD+ Display', '16.59 cm (6.53 inch) HD+ Display', '17.02 cm (6.7 inch) HD+ Display', '15.49 cm (6.1 inch) Liquid Retina HD Display', '15.49 cm (6.1 inch) Liquid Retina HD Display', '16.51 cm (6.5 inch) HD+ Display', '16.51 cm (6.5 inch) HD+ Display', '16.51 cm (6.5 inch) HD+ Display', '16.51 cm (6.5 inch) HD+ Display', '16.51 cm (6.5 inch) HD+ Display', '16.51 cm (6.5 inch) HD+ Display', '16.51 cm (6.5 inch) HD+ Display', '15.49 cm (6.1 inch) Super Retina XDR Display', '16.59 cm (6.53 inch) HD+ Display', '17.02 cm (6.7 inch) HD+ Display', '16.51 cm (6.5 inch) HD+ Display', '16.51 cm (6.5 inch) HD+ Display', '17.02 cm (6.7 inch) HD+ Display']

# %%
#scraping the Battery 
B=driver.find_elements(By.XPATH,"//ul[@class='_1xgFaf']//li[4]")
for i in B:
    if i.text is None :
        Battery.append("--") 
    else:
        Battery.append(i.text)
print(Battery)
# Out:
# ['6000 mAh Lithium Ion Battery', '6000 mAh Lithium Ion Battery', '6000 mAh Lithium Ion Battery', 'A13 Bionic Chip Processor', 'A13 Bionic Chip Processor', 'A13 Bionic Chip Processor', '5000 mAh Lithium-ion Polymer Battery', '5000 mAh Lithium-ion Polymer Battery', '6000 mAh Lithium Polymer Battery', 'A13 Bionic Chip Processor', 'A13 Bionic Chip Processor', '5000 mAh Lithium Ion Battery', '5000 mAh Lithium Ion Battery', '5000 mAh Lithium Ion Battery', '5000 mAh Lithium Ion Battery', '5000 mAh Lithium Ion Battery', '5000 mAh Lithium Ion Battery', '5000 mAh Lithium Ion Battery', 'A15 Bionic Chip Processor', '5000 mAh Lithium-ion Polymer Battery', '6000 mAh Lithium Polymer Battery', '5000 mAh Lithium Ion Battery', '5000 mAh Lithium Ion Battery', '6000 mAh Lithium Polymer Battery']

# %%
#scraping the Price 
pr=driver.find_elements(By.XPATH,"//div[@class='_30jeq3 _1_WHN1']")
for i in pr:
    if i.text is None :
        Price.append("--") 
    else:
        Price.append(i.text)
print(Price)
# Out:
# ['₹9,499', '₹9,499', '₹9,499', '₹41,990', '₹42,990', '₹36,990', '₹6,666', '₹7,777', '₹8,999', '₹35,990', '₹41,990', '₹6,110', '₹6,110', '₹6,110', '₹8,249', '₹8,249', '₹8,999', '₹8,999', '₹57,990', '₹6,666', '₹8,999', '₹8,249', '₹8,999', '₹8,999']

# %%
#scraping the URL
u=driver.find_elements(By.XPATH,"//a[@class='_1fQZEK']")
for i in u:
    if i.text is None :
        url.append("--") 
    else:
        url.append(i.get_attribute("href"))
print(url)
# Out:
# ['https://www.flipkart.com/samsung-galaxy-f13-nightsky-green-64-gb/p/itmeadfda1bd23fa?pid=MOBGENJWF4KJTPEN&lid=LSTMOBGENJWF4KJTPENAUQVSZ&marketplace=FLIPKART&q=Smartphone&store=tyy%2F4io&srno=s_1_1&otracker=search&otracker1=search&fm=organic&iid=c914f6dc-f852-4928-b030-e5c6ea9c29a7.MOBGENJWF4KJTPEN.SEARCH&ppt=hp&ppn=homepage&ssid=05l1n9ukcg0000001664202420601&qH=853ca16bda4f3d30', 'https://www.flipkart.com/samsung-galaxy-f13-waterfall-blue-64-gb/p/itm583ef432b2b0c?pid=MOBGENJWBPFYJSFT&lid=LSTMOBGENJWBPFYJSFT1ZY7B0&marketplace=FLIPKART&q=Smartphone&store=tyy%2F4io&srno=s_1_2&otracker=search&otracker1=search&fm=organic&iid=c914f6dc-f852-4928-b030-e5c6ea9c29a7.MOBGENJWBPFYJSFT.SEARCH&ppt=hp&ppn=homepage&ssid=05l1n9ukcg0000001664202420601&qH=853ca16bda4f3d30', 'https://www.flipkart.com/samsung-galaxy-f13-sunrise-copper-64-gb/p/itm0d8c65ec17621?pid=MOBGENJWWRYSFC5P&lid=LSTMOBGENJWWRYSFC5PYXUAZH&marketplace=FLIPKART&q=Smartphone&store=tyy%2F4io&srno=s_1_3&otracker=search&otracker1=search&f
# ...

# %%
data=pd.DataFrame({"Brand":brand,"Color":Color,"Storage-RAM,ROM":Storage_RAM_ROM,"Camera":camera,"Display":disp,"Battery":Battery,"Price":Price,"URL":url})
data
# Out:
#                   Brand                    Color  \
# 0   SAMSUNG Galaxy F13    Nightsky Green, 64 GB)
# 1   SAMSUNG Galaxy F13    Waterfall Blue, 64 GB)
# 2   SAMSUNG Galaxy F13    Sunrise Copper, 64 GB)
# 3      APPLE iPhone 11            Black, 128 GB)
# 4      APPLE iPhone 11            White, 128 GB)
# 5      APPLE iPhone 11             White, 64 GB)
# 6             POCO C31        Royal Blue, 32 GB)
# 7             POCO C31        Royal Blue, 64 GB)
# 8             REDMI 10      Pacific Blue, 64 GB)
# 9      APPLE iPhone 11             Black, 64 GB)
# 10     APPLE iPhone 11           Purple, 128 GB)
# 11          realme C30      Bamboo Green, 32 GB)
# 12          realme C30       Denim Black, 32 GB)
# 13          realme C30         Lake Blue, 32 GB)
# 14          realme C33        Sandy Gold, 32 GB)
# 15          realme C33         Aqua Blue, 32 GB)
# 16          realme C33         Aqua Blue, 64 GB)
# 17          realme C33         Night Sea, 64 GB)
# ...

# %% [markdown]
# # Question 5

# %%
import pandas as pd
import selenium
from selenium import webdriver
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException
import time
import re

# %%
driver=webdriver.Chrome(r"chromedriver.exe")

# %%
#Opening the website on automated website
driver.get("https://www.google.co.in/maps")

# %%
time.sleep(3)
city = input('Enter City Name : ')                                         # Enter city to be searched
search = driver.find_element("id","searchboxinput")                       # locating search bar
search.clear()                                                             # clearing search bar
time.sleep(2)
search.send_keys(city)                                                     # entering values in search bar
button = driver.find_element(By.XPATH,"//button[@class='mL3xi']")               # locating search button
button.click()                                                             # clicking search button
time.sleep(3)
# Out:
# Enter City Name : Bangalore

# %%
try:
    url_string = driver.current_url
    print("URL Extracted: ", url_string)
    lat_lng = re.findall(r'@(.*)data',url_string)
    if len(lat_lng):
        lat_lng_list = lat_lng[0].split(",")
        if len(lat_lng_list)>=2:
            lat = lat_lng_list[0]
            lng = lat_lng_list[1]
        print("Latitude = {}, Longitude = {}".format(lat, lng))

except Exception as e:
        print("Error: ", str(e))
# Out:
# URL Extracted:  https://www.google.co.in/maps/place/Bengaluru,+Karnataka/@17.449522,78.4956941,14z/data=!4m5!3m4!1s0x3bae1670c9b44e6d:0xf8dfc3e8517e4fe0!8m2!3d12.9715987!4d77.5945627
# Latitude = 17.449522, Longitude = 78.4956941

# %% [markdown]
# # Question 6

# %%
import pandas as pd
import selenium
from selenium import webdriver
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException
import time
import re
from selenium.webdriver.common.by import By

# %%
driver=webdriver.Chrome(r"chromedriver.exe")

# %%
#Opening the website on automated website
driver.get("https://trak.in/india-startup-funding-investment-2015/")

# %%
date=[]
company=[]
industry=[]
investor=[]
inv_type=[]
amount=[]

# %%
#scraping the company_name 
companies=driver.find_elements(By.XPATH,"//td[@class='column-3']")
for i in companies:
    if i.text is None :
        company.append("--") 
    else:
        company.append(i.text)
print(company)
# Out:
# ['BYJU’S', 'Meesho', 'Swiggy', 'Groww', 'Beldara', 'DealShare', 'Uniphore', 'Dunzo', 'BYJU’S', 'SkilloVilla', 'CityMall', 'DotPe', 'Doubtnut', 'Zomato', 'Fingerlix', 'Zolve', 'KreditBee', 'Pepperfry', 'Grofers', 'Nothing', 'SplashLearn', 'Digit Insurance', 'Bombay Shaving Company', 'DeHaat', 'Darwinbox', 'mfine', 'Udayy', 'True Elements', 'Saveo', 'Bira 91', 'Pine Labs', 'Zenoti', 'Tax Buddy India', 'Delhivery', 'PagarBook', 'Codingal', 'CRED', 'Bira 91', 'Chumbak', 'Cityflo', 'Shipsy', 'Unacademy', 'Cashfree', 'Credgenics', 'Country Delight', 'Nykaa', 'Betterplace', 'FlexiLoans', 'GetVantage', 'FreshToHome', 'Origo', 'Origo', 'Treebo Hotels', 'Hubilo', 'CredAble', 'Byju’s', 'mCaffeine', 'Qshala', 'Winzo', 'Hippo Video', 'Melorra', '1mg', 'mfine', 'Apna', 'Railofy', 'Practo', 'Medlife', 'HungerBox', 'Dunzo', 'Terra.do', 'Classplus', 'Niyo', 'ZestMoney', 'FreshToHome', 'Eduvanz', 'Flipkart', 'Vedantu', 'Crio', 'goDutch', 'Mystifly', 'JetSynthesys', 'gigIndia', 'PumPumPum', 'FLYX', 'Op
# ...

# %%
#scraping the Industry 
ind=driver.find_elements(By.XPATH,"//td[@class='column-4']")
for i in ind:
    if i.text is None :
        industry.append("--") 
    else:
        industry.append(i.text)
print(industry)
# Out:
# ['Edu-tech', 'E-commerce', 'Online Food Delivery', 'FinTech', 'E-commerce', 'E-commerce', 'Technology', 'E-commerce', 'Edu-tech', 'Edu-tech', 'E-commerce', 'FinTech', 'Edu Tech', 'Hospitality', 'Hospitality', 'FinTech', 'Finance', 'E-commerce', 'E-Commerce', 'Technology', 'EdTech', 'Financial Services', 'Consumer Goods Company', 'AgriTech Startup', 'SaaS', 'Health Tech Startup', 'EdTech', 'Food Startup', 'B2B E-commerce', 'Food and Beverage', 'Financial Services', 'Technology Provider', 'FinTech', 'Supply chain', 'SaaS', 'EduTech', 'Financial Services', 'Food and Beverage', 'Lifestyle', 'Transportation', 'SaaS', 'Edutech', 'FinTech', 'Fintech', 'Dairy Tech', 'E-commerce', 'Digital Solutions', 'FinTech', 'FinTech', 'E-commerce', 'AgriTech', 'Advertising', 'Hospitality', 'Information Technology', 'FinTech', 'EduTech', 'Personal Care', 'EduTech', 'Online Gaming', 'Video Customer Experience(CX) Platform', 'E-commerce', 'E-commerce', 'HealthTech', 'Human Resources', 'Transportation', 'Hea
# ...

# %%
#scraping the Dates 
dt=driver.find_elements(By.XPATH,"//td[@class='column-2']")
for i in dt:
    if i.text is None :
        date.append("--") 
    else:
        date.append(i.text)
print(date)
# Out:
# ['01/04/2021', '05/04/2021', '14/04/2021', '07/04/2021', '14/04/2021', '04/03/2021', '31/03/2021', '30/03/2021', '30/03/2021', '23/03/2021', '25/03/2021', '26/03/2021', '11/02/2021', '22/02/2021', '19/02/2021', '17/02/2021', '15/02/2021', '12/02/2021', '12/02/2021', '09/02/2021', '09/02/2021', '15/01/2021', '28/01/2021', '19/01/2021', '19/01/2021', '18/01/2021', '18/01/2021', '11/01/2021', '13/01/2021', '15/12/2020', '21/12/2020', '15/12/2020', '22/12/2020', '15/12/2020', '18/12/2020', '30/11/2020', '30/11/2020', '29/11/2020', '27/11/2020', '25/11/2020', '25/11/2020', '25/11/2020', '24/11/2020', '30/11/2020', '23/11/2020', '28/10/2020', '28/10/2020', '28/10/2020', '27/10/2020', '27/10/2020', '27/10/2020', '27/10/2020', '15/10/2020', '26/10/2020', '28/10/2020', '08/09/2020', '12/09/2020', '09/09/2020', '02/09/2020', '09/09/2020', '07/09/2020', '07/09/2020', '31/08/2020', '31/08/2020', '03/09/2020', '15/08/2020', '13/08/2020', '13/08/2020', '04/08/2020', '11/08/2020', '12/08/2020', '14
# ...

# %%
#scraping the Investor_Name 
IN=driver.find_elements(By.XPATH,"//td[@class='column-7']")
for i in IN:
    if i.text is None :
        investor.append("--") 
    else:
        investor.append(i.text)
print(investor)
# Out:
# ['Innoven Capital', 'SoftBank Vision Fund 2', 'Amansa Holdings, Carmignac, Falcon Edge Capital, Goldman Sachs, Think Investments', 'MC Global Edtech, B Capital, Baron, others', 'Hindustan Media Ventures', 'Innoven Capital', 'Sorenson Capital Partners', 'Krishtal Advisors Pte Ltd', 'MC Global Edtech, B Capital, Baron, others', 'Titan Capital, others', 'Accel Partners', 'PayU', 'SIG Global, Sequoia Capital, WaterBridge Ventures and ON Mauritius', 'Tiger Global, Kora', 'Rhodium Trust, Accel Partners and Swiggy', 'Accel Partners and Lightspeed Venture Partners', 'Azim Premji’s PremjiInvest and South Korea’s Mirae Asset Venture', 'InnoVen Capital', 'SoftBank Vision Fund (SVF)', 'GV', 'Owl Ventures', 'A91 Partners, Faering Capital, TVS Capital Funds', 'Reckitt Benckiser', 'Prosus Ventures', 'Salesforce Ventures', 'Heritas Capital Management', 'Sequoia Capital', 'SIDBI Venture Capital', 'Matrix Partners India, RTP Global, others', 'Nishant Mittal, Pankaj Chaddah and Shikha Sunil Chandak', '
# ...

# %%
#scraping the Investment_Type 
IT=driver.find_elements(By.XPATH,"//td[@class='column-8']")
for i in IT:
    if i.text is None :
        inv_type.append("--") 
    else:
        inv_type.append(i.text)
print(inv_type)
# Out:
# ['Series F', 'Series E', 'Series J', 'Series D', 'Venture', 'Debt Financing', 'Series D', 'Series E', 'Series F', 'Seed', 'Series A', 'Series A', 'Series B', 'Venture', 'Series C', 'Seed', 'Series C', 'Debt Financing', 'Unspecified', 'Series A', 'Series C', 'Venture', 'Venture', 'Series C', 'Seed', 'Venture Round', 'Seed Funding', 'Series', 'Seed', 'Funding', 'Secondary Market', 'Series D', 'Seed', 'Secondary Market', 'Series A', 'Seed', 'Series C', 'Bridge Funding', 'Pre-series E', 'Series A', 'Series A', 'Venture', 'Series B', 'Pre-Series A', 'Series C', 'Personal Investment', 'Series B', 'Equity and Debt', 'Seed', 'Series C', 'Debt', 'Series A', '', 'Seed', 'Follow-On', 'Private Equity', 'Series B', 'Angel', 'Series B', 'Series A', 'Debt Financing', 'In Progress', 'Series B', 'Series A', 'Seed', 'Series F', '', 'Series D1', 'In Progress', 'Seed', 'In Progress', '', '', 'Venture', 'Series A', 'M&A', 'Series D', 'pre-Series A', 'Seed', 'pre-Series B', 'Venture-Series Unknown', 'pre-
# ...

# %%
#scraping the Amount 
Price=driver.find_elements(By.XPATH,"//td[@class='column-9']")
for i in Price:
    if i.text is None :
        amount.append("--") 
    else:
        amount.append(i.text)
print(amount)
# Out:
# ['460,000,000', '300,000,000', '343,000,000', '83,000,000', '7,400,000', '250,000,000', '140,000,000', '8,000,000', '460,000,000', '300,000,000', '11,000,000', '27,500,000', '2,500,000', '250,000,000', '2,747,045.20', '1,50,00,000', '75,000,000', '4,773,958', '55,000,000', '15,000,000', '18,000,000', '1,80,00,000', '6,172,258.50', '30,000,000', '15,000,000', '16,000,000', '15,000,000', '100,000,000', '4,000,000', '1,273,634.07', 'Undisclosed', '160,000,000', '1,000,000', '25,000,000', '15,000,000', '560,000', '80,000,000', '3,000,000', '1,001,047.92', '7,700,000', '6,003,806', '75,000,000-100,000,000', '35,300,000', '3,500,000', '25,000,000', 'NA', '10,000,000', '20,160,000', '5,000,000', '121,000,000', '4,700,000', '15,000,000', '6,000,000', '4,500,000', '4,500,000', '500,000,000', '3,000,000', '370,000', '15,500,000', '4,500,000', 'upto 8,900,000', '100,000,000', '5,400,000', '8,000,000', '950,000', '32,000,000', '23,000,000', '1,560,000', '30,000,000', '1,400,000', 'upto 15,000,00
# ...

# %%
funding=pd.DataFrame([])
funding['Company']=company[5:29]
funding['Industry']=industry[5:29]
funding['Investor_Name']=investor[5:29]
funding['Amount Invested']=amount[5:29]
funding['Specification']=inv_type[5:29]
funding['Dates']=date[5:29]
funding
# Out:
#                    Company                Industry  \
# 0                DealShare              E-commerce
# 1                 Uniphore              Technology
# 2                    Dunzo              E-commerce
# 3                   BYJU’S                Edu-tech
# 4              SkilloVilla                Edu-tech
# 5                 CityMall              E-commerce
# 6                    DotPe                 FinTech
# 7                 Doubtnut                Edu Tech
# 8                   Zomato             Hospitality
# 9                Fingerlix             Hospitality
# 10                   Zolve                 FinTech
# 11               KreditBee                 Finance
# 12               Pepperfry              E-commerce
# 13                 Grofers              E-Commerce
# 14                 Nothing              Technology
# 15             SplashLearn                  EdTech
# 16         Digit Insurance      Financial Services
# ...

# %% [markdown]
# # Question 7

# %%
import pandas as pd
import selenium
from selenium import webdriver
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException
import time
import re
from selenium.webdriver.common.by import By

# %%
driver=webdriver.Chrome(r"chromedriver.exe")

# %%
#Opening the website on automated website
driver.get("https://www.digit.in/top-products/best-gaming-laptops-40.html")

# %%
brands=[]
description=[]
spec=[]
price=[]

# %%
#Scraping Brands
br=driver.find_elements(By.XPATH,"//div[@class='TopNumbeHeading']")

# %%
for i in br:
    brands.append(str(i.text).replace("\n",""))
brands
# Out:
# ['1.MSI Titan GT77-12UHS',
#  '2.Alienware X17 R2',
#  '3.Acer Predator Triton 500 SE PT516-52s',
#  '4.Omen By HP (16-B1371TX)',
#  '5.Acer Predator Helios 300 AN515-45 (NH.QBRSI.0',
#  '6.MSI Delta 15 (A5EFK-083IN)',
#  '7.Omen By HP (16-C0141AX)',
#  '8.Lenovo Legion 5i Pro (82RF00MGIN)',
#  '9.Alienware M15 R5 Ryzen Edition Icc-C780001win',
#  '10.Lenovo Slim 7 Gen 6 (82K8002JIN)']

# %%
#Scraping specification
sp=driver.find_elements(By.XPATH,"//div[@class='Specs-Wrap']")
for i in sp:
    spec.append(str(i.text).replace("\n",""))
spec
# Out:
# ['Windows 11 Home OS17.3" (3840 x 2160) Display12th Gen Intel Core i9-12900HX | NA Processor2 TB SSD/64 GB DDR5 Memory',
#  'Windows 11 Home OS17.3" (1920 x 1080) Display12th Gen Intel Core i9-12900H | 5 GHz Processor1 TB SSD/32 GB DDR5 Memory',
#  'Windows 11 Home OS16" (2560 x 1600) Display12th Gen Intel Core i7-12700H | 3.50 GHz Processor2 TB SSD/32 GB DDR5 Memory',
#  'Windows 11 Home OS16.1" (2560 x 1440) Display12th Gen Intel Core i7-12700H | 4.7 GHz Processor1 TB SSD/8 GB DDR5 Memory',
#  'Windows 11 Home OS15.6" (2560 x 1440) DisplayAMD Ryzen 9-5900HX | NA Processor512 GB SSD/16 GB DDR4 Memory',
#  'Windows 11 Home OS15.6" (1920 x 1080) DisplayAMD 5th Gen Ryzen 9-5900HX | 3.3GHz Processor1 TB SSD/16 GBGB DDR4 Memory',
#  'Windows 11 Home OS16.1" (2560 x 1440) DisplayAMD Ryzen™ 9 5900HX | 3.3 GHz Processor1 TB NVMe/16 GB DDR4 Memory',
#  'Windows 11 Home OS16" (2560 x 1600) Display12th Gen Intel Core i7-12700H | 2.3 GHz Processor1 TB SSD/16 GB DDR5 Memory',
# ...

# %%
#Scraping Description
des=driver.find_elements(By.XPATH,"//div[@class='Section-center']")
for i in des:
    description.append(str(i.text).replace("\n",""))
description
# Out:
# ['The very best MSI gaming laptop featuring an Intel processor is the MSI TITAN GT77 - 12UHS. This is the top of the line model from MSI’s recent refresh of their entire gaming lineup and is powered by the Intel Core i9-12900HX which is a 16 Core (8P+8E) processor that has 24 threads and a maximum Turbo power of 157 Watts. The graphics card in this laptop is the NVIDIA RTX 3080 Ti and it too sports a high TGP of 175 Watts. This is one of the most powerful CPU+GPU combinations with plenty of thermal headroom to allow it to operate at higher clock speeds for longer time periods. As for the memory, the MSI GT77-12UHS can have up to 128 GB of DDR5 memory but ships with 64 GB DDR5 clocked at 4800 MT/s. Being a 12th Gen machine also means that the motherboard has PCIe Gen 5.0 lanes for storage devices such as M.2 SSDs. The GT77-12UHS has four M.2 slots of which one slot is PCIe Gen 5 whereas the remaining three are PCIe Gen 4 slots. Then there’s also the display, the GT77-12UHS features a 
# ...

# %%
#Scraping price
pri=driver.find_elements(By.XPATH,"//td[@class='smprice']")
for i in pri:
    price.append(str(i.text).replace("\n",""))
price
# Out:
# ['N/A',
#  '₹ 389,990',
#  '₹ 300,000',
#  '₹ 171,490',
#  '₹ 172,999',
#  '₹ 188,990',
#  '₹ 124,990',
#  '₹ 163,369',
#  '₹ 144,990',
#  '₹ 131,790']

# %%
lap=pd.DataFrame([])
lap['Brands']=brands[0:10]
lap['Price']=price[0:10]
lap['Specification']=spec[0:10]
lap['Description']=description[0:10]
lap
# Out:
#                                             Brands      Price  \
# 0                           1.MSI Titan GT77-12UHS        N/A
# 1                               2.Alienware X17 R2  ₹ 389,990
# 2          3.Acer Predator Triton 500 SE PT516-52s  ₹ 300,000
# 3                        4.Omen By HP (16-B1371TX)  ₹ 171,490
# 4  5.Acer Predator Helios 300 AN515-45 (NH.QBRSI.0  ₹ 172,999
# 5                     6.MSI Delta 15 (A5EFK-083IN)  ₹ 188,990
# 6                        7.Omen By HP (16-C0141AX)  ₹ 124,990
# 7              8.Lenovo Legion 5i Pro (82RF00MGIN)  ₹ 163,369
# 8  9.Alienware M15 R5 Ryzen Edition Icc-C780001win  ₹ 144,990
# 9              10.Lenovo Slim 7 Gen 6 (82K8002JIN)  ₹ 131,790
#
#                                        Specification  \
# 0  Windows 11 Home OS17.3" (3840 x 2160) Display1...
# 1  Windows 11 Home OS17.3" (1920 x 1080) Display1...
# 2  Windows 11 Home OS16" (2560 x 1600) Display12t...
# 3  Windows 11 Home OS16.1" (2560 x 1440) Display1...
# ...

# %% [markdown]
# # Question 8

# %%
import pandas as pd
import selenium
from selenium import webdriver
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException
import time
import re
from selenium.webdriver.common.by import By

# %%
driver=webdriver.Chrome(r"chromedriver.exe")

# %%
#Opening the website on automated website
driver.get("https://www.forbes.com/billionaires/")

# %%
#Creating empty lists
rank=[]
name=[]
networth=[]
age=[]
citizenship=[]
source=[]
industry=[]

# %%
#Scraping rank
a=driver.find_elements(By.XPATH,"//div[@class='rank']")
for i in a:
    rank.append(i.text)

# %%
#Scraping Name
b=driver.find_elements(By.XPATH,"//div[@class='personName']")
for i in b:
    name.append(i.text)

# %%
#Scraping networth
c=driver.find_elements(By.XPATH,"//div[@class='netWorth']")
for i in c:
    networth.append(i.text)

# %%
#Scraping Age
d=driver.find_elements(By.XPATH,"//div[@class='age']")
for i in d:
    age.append(i.text)

# %%
#Scraping citizenship
e=driver.find_elements(By.XPATH,"//div[@class='countryOfCitizenship']")
for i in e:
    citizenship.append(i.text)

# %%
#Scraping Source
f=driver.find_elements(By.XPATH,"//div[@class='source']")
for i in f:
    source.append(i.text)

# %%
#Scraping Industry
g=driver.find_elements(By.XPATH,"//div[@class='category']")
for i in g:
    industry.append(i.text)

# %%
forbes=pd.DataFrame([])
forbes['Rank']=rank
forbes['Name']=name
forbes['Net Worth']=networth
forbes['Age']=age
forbes['Citizenship']=citizenship
forbes['Source']=source
forbes['Industry']=industry
forbes
# Out:
#      Rank                      Name Net Worth Age    Citizenship  \
# 0      1.                 Elon Musk    $219 B  50  United States
# 1      2.                Jeff Bezos    $171 B  58  United States
# 2      3.  Bernard Arnault & family    $158 B  73         France
# 3      4.                Bill Gates    $129 B  66  United States
# 4      5.            Warren Buffett    $118 B  91  United States
# ..    ...                       ...       ...  ..            ...
# 195  192.    Marcel Herrmann Telles   $10.3 B  72         Brazil
# 196  197.                Leon Black     $10 B  70  United States
# 197  197.                Joe Gebbia     $10 B  40  United States
# 198  197.              David Geffen     $10 B  79  United States
# 199  197.                Yu Renrong     $10 B  56          China
#
#                     Source               Industry
# 0            Tesla, SpaceX             Automotive
# 1                   Amazon             Technology
# ...

# %% [markdown]
# # Question 9

# %%
import pandas as pd
import selenium
from selenium import webdriver
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException
from  time import sleep
import re
from selenium.webdriver.common.by import By

# %%
driver=webdriver.Chrome(r"chromedriver.exe")

# %%
#Opening the website on automated website
driver.get("https://www.youtube.com/watch?v=26QPDBe-NB8")

# %%
#Creating empty lists
comment=[]
upvote=[]
t=[]

# %%
for i in range(30):
    driver.execute_script("window.scrollBy(0,40)")
    sleep(5)
    a=driver.find_elements(By.XPATH,"//yt-formatted-string[@class='style-scope ytd-comment-renderer']")
    for i in a:
        comment.append(i.text)
    b=driver.find_elements(By.XPATH,"//yt-formatted-string[@class='published-time-text style-scope ytd-comment-renderer']")
    for i in b:
        t.append(i.text)
    c=driver.find_elements(By.XPATH,"//span[@class='style-scope ytd-comment-action-buttons-renderer']")
    for i in c:
        upvote.append(i.text)

# %%
#Sorting out upvotes
up=upvote[1::2]

# %%
video=pd.DataFrame([])
video['Comment']=comment
video['Time Posted']=t
video['Upvotes']=up
video
# Out:
#                                                Comment           Time Posted  \
# 0    Thank you to the presenter. She did an amazing...  3 years ago (edited)
# 1    As a Linux kernel developer, I watched the who...           5 years ago
# 2    I love this show! I've learned so much from it...           5 years ago
# 3    Who else had a brief moment of panic at 11:38 ...           5 years ago
# 4    CrashCourse, you have helped me with satisfyin...           4 years ago
# ..                                                 ...                   ...
# 515  Wow! great video! amazingly well structured an...           4 years ago
# 516  wow, this is a lot and I mean A LOT of informa...           3 weeks ago
# 517  As someone who has worked with mainframe tech ...           4 years ago
# 518  Your videos are awesome! Thank you crashcourse!!!           5 years ago
# 519  You should have talked about Gary Kildall - th...  4 years ago (edited)
#
#     Upvotes
# 0       316
# 1        48
# ...

# %% [markdown]
# # Question 10

# %%
import pandas as pd
import selenium
from selenium import webdriver
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException
import time
import re
from selenium.webdriver.common.by import By
import time

# %%
driver=webdriver.Chrome(r"chromedriver.exe")
# Out:
# C:\Users\vaish\AppData\Local\Temp\ipykernel_19164\191662975.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver=webdriver.Chrome(r"chromedriver.exe")

# %%
#Opening the website on automated website
driver.get("https://www.hostelworld.com/")

# %%
a=driver.find_element(By.XPATH,"//*[@id='search-input-field']")
a.click()
a.send_keys("London")

# %%
b=driver.find_element(By.XPATH,"//*[@id='predicted-search-results']")
b.click()

# %%
c=driver.find_element(By.XPATH,"/html/body/div[3]/div/div/div[2]/div[1]/div/div/div[4]/div/div[2]/div/div[5]/button")
c.click()

# %%
name=[]
distance=[]
total_rev=[]
over_rev=[]
s=[]
priv=[]
dorm=[]
fac=[]
des=[]

# %%
 #Scraping name
d=driver.find_elements(By.XPATH,"//h2[@class='title title-6']")
for i in d:
    name.append(i.text)
        
#Scraping distance
e=driver.find_elements(By.XPATH,"//span[@class='description']")
for i in e:
    distance.append(i.text)
               
#Scraping total reviews
g=driver.find_elements(By.XPATH,"//div[@class='reviews']")
for i in g:
    total_rev.append(i.text)
    
    
#Scraping overall reviews
h=driver.find_elements(By.XPATH,"//div[@class='keyword']")
for i in h:
    s.append(i.text)
    over_rev=s[2:]
        
#Scraping Private and Dorm Room  Price
j=driver.find_elements(By.XPATH,"//div[@class='price-col']")
s1=[]
for i in j:
    s1.append(i.text)
priv=s1[::2]
dorm=s1[1::2]
    
#Scraping Facilities
l=driver.find_elements(By.XPATH,"//div[@class='facilities-label facilities']")
for i in l:
    fac.append(i.text)

# %%
urls=[]
page_urls=driver.find_elements(By.XPATH,"//a[@class='view-button']")
# appending all the urls on current page to urls list
for url in page_urls:
    urls.append(url.get_attribute("href"))

# %%
for url in urls:
    driver.get(url)                                                        # Loading the webpage by url
    print("Scraping URL = ", url)
    time.sleep(2)
    try:
        k=driver.find_element(By.XPATH,"//div[@class='content collapse-content']")
        des.append(k.text)
    except NoSuchElementException:
        des.append("No content")
# Out:
# Scraping URL =  https://www.hostelworld.com/pwa/hosteldetails.php/St-Christopher-s-Village/London/502?from=2022-09-27&to=2022-09-30&guests=2
# Scraping URL =  https://www.hostelworld.com/pwa/hosteldetails.php/Urbany-Hostel-London/London/303427?from=2022-09-27&to=2022-09-30&guests=2
# Scraping URL =  https://www.hostelworld.com/pwa/hosteldetails.php/Generator-London/London/510?from=2022-09-27&to=2022-09-30&guests=2
# Scraping URL =  https://www.hostelworld.com/pwa/hosteldetails.php/Safestay-London-Elephant-Castle/London/55551?from=2022-09-27&to=2022-09-30&guests=2
# Scraping URL =  https://www.hostelworld.com/pwa/hosteldetails.php/Safestay-London-Kensington-Holland-Park/London/93920?from=2022-09-27&to=2022-09-30&guests=2
# Scraping URL =  https://www.hostelworld.com/pwa/hosteldetails.php/Phoenix-Hostel/London/48221?from=2022-09-27&to=2022-09-30&guests=2
# ...

# %%
hostel=pd.DataFrame([])
hostel['Name']=name
hostel['Distance']=distance
hostel['Total Reviews']=total_rev
hostel['Overall Reviews']=over_rev
hostel["Private Room Price"]=priv
hostel["Dorm Room Price"]=dorm
hostel["Facilities"]=fac
hostel["Description"]=des
hostel
# Out:
#                                        Name  \
# 0                  St Christopher's Village
# 1                      Urbany Hostel London
# 2                          Generator London
# 3         Safestay London Elephant & Castle
# 4   Safestay London Kensington Holland Park
# 5                            Phoenix Hostel
# 6              St Christopher's Hammersmith
# 7        Destinations Hostels @ The Gallery
# 8                   Saint James Backpackers
# 9           St Christopher's Shepherds Bush
# 10                            Selina Camden
# 11                       Strand Continental
# 12               PubLove @ The Rose & Crown
# 13                   London Waterloo Hostel
# 14                       Book a Bed Hostels
# 15           PubLove @ The Crown, Battersea
# 16                      Britannia Inn Hotel
# 17                       City Hotel Carlton
# 18                                Kip Hotel
# 19                            Elmwood Hotel
# ...
